# %%
# !pip install openai==1.82.0
# Out:
# Collecting openai==1.82.0
#   Using cached openai-1.82.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sherry\miniconda3\lib\site-packages (from openai==1.82.0) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sherry\miniconda3\lib\site-packages (from openai==1.82.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sherry\miniconda3\lib\site-packages (from openai==1.82.0) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai==1.82.0)
#   Downloading jiter-0.12.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\sherry\miniconda3\lib\site-packages (from openai==1.82.0) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\sherry\miniconda3\lib\site-packages (from openai==1.82.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\sherry\miniconda3\lib\site-packages (from openai==1.82.0) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\sherry\miniconda3\lib\site-packages (from openai==1.82.0) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\sherry\miniconda3\lib\site-packages (from anyio<5,>=3.5.0->openai==1.82.0) (3.11)
# Requirement already satisfied: certifi in c:\users\sherry\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->openai==1.82.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sherry\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->openai==1.82.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sherry\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.82.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sherry\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.82.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sherry\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.82.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sherry\miniconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.82.0) (0.4.2)
# Requirement already satisfied: colorama in c:\users\sherry\miniconda3\lib\site-packages (from tqdm>4->openai==1.82.0) (0.4.6)
# Using cached openai-1.82.0-py3-none-any.whl (720 kB)
# Downloading jiter-0.12.0-cp313-cp313-win_amd64.whl (204 kB)
# Installing collected packages: jiter, openai
#
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    ---------------------------------------- 2/2 [openai]
#
# Successfully installed jiter-0.12.0 openai-1.82.0

# %%
import os
from openai import OpenAI

# 从环境变量获取 DeepSeek API Key
api_key = os.getenv("DEEPSEEK_API_KEY")
if not api_key:
    raise ValueError("请设置 DEEPSEEK_API_KEY 环境变量")

# 初始化 OpenAI 客户端（假设 DeepSeek 的 API 兼容 OpenAI 格式）
client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com",  # DeepSeek API 的基地址
)

# 定义提示词
prompt = """请帮我用 HTML 生成一个五子棋游戏，所有代码都保存在一个 HTML 中。"""

# %%
try:
    # 调用 DeepSeek Chat API
    response = client.chat.completions.create(
        model="deepseek-chat",  # 或 DeepSeek 提供的其他模型名称
        messages=[
            {"role": "system", "content": "你是一个专业的 Web 开发助手，擅长用 HTML/CSS/JavaScript 编写游戏。"},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,
        stream=False
    )

    # 提取生成的 HTML 内容
    if response.choices and len(response.choices) > 0:
        html_content = response.choices[0].message.content
        
        # 保存到文件
        with open("gomoku.html", "w", encoding="utf-8") as f:
            f.write(html_content)
        print("五子棋游戏已保存为 gomoku.html")
    else:
        print("未收到有效响应")

except Exception as e:
    print(f"调用 API 出错: {e}")
# Out:
# 五子棋游戏已保存为 gomoku.html
